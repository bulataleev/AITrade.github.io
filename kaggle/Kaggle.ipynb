# 36987                       465                                    7
# 36988                        31                                    1
# 36989                        71                                    6
# 36990                      4482                                  206
# 36991                         9                                    0
# 36992                       842                                   44
# 36993                        22                                    0
# 36994                        80                                    7
# 36995                         1                                    0
# 36996                        92                                    5
# 36997                        61                                    3
# 36998                         1                                    0
# 36999                       318                                    2
#
#                                                    Title  \
# 0      GET/Post values don't be refreshed/parsed by t...
# 1                              Search control in Haskell
# 2      jQuery: event.preventdefault not working with ...
# 3                              java 2 dimensional arrays
# 4      Which interface is used to detect key events f...
# 5                                    Own Cydia App crash
# 6      how to remove small space in every column in f...
# 7                         PHP strtr does not work at all
# 8            Higher accuracy on placing bounding spheres
# 9      Is "double hashing" a password less secure tha...
# 10     Error with WP7 Silverlight - No Overload for "...
# 11                         Ctor not allowed return type.
# 12     Subsume external library into source tree with...
# 13              javascript check and replace two strings
# 14                  server issue for uploading my folder
# 15     Does XMLConfiguration in Apache common surport...
# 16                         Windows XP remote login issue
# 17                              Python: Average Rainfall
# 18     How to override Equals on a object created by ...
# 19     How is this MIPS assembly conversion of this C...
# 20     send argument from jsp to struts2 action class...
# 21                SSIS - lookup surrogate key for parent
# 22     Can Intents/Intent Filters be used for more mu...
# 23                       what does the below codes do...
# 24          how to add a newly created node to linklist?
# 25                                  Raw_string in Python
# 26                   Why Asp.net MVC and not Asp.net MVP
# 27                                 Incremental clusterig
# 28                          zipping files in parts in C#
# 29                               MySQL Primary Key Issue
# ...                                                  ...
# 36970  Expert please be advice for this technique in OOP
# 36971                     Highlight code java in android
# 36972                    php printing a message in a div
# 36973  OpenGL 3.x .obj loader with ADS Phong "veiny-l...
# 36974                        Drop down table and jquery
# 36975  Performance of C++ vs Virtual Machine language...
# 36976                                    ajax form input
# 36977         IE 9 does not run this jQuery if statement
# 36978  Where are people getting that rotaty loading i...
# 36979                     Resolve potential memory leaks
# 36980            Merge Sort in Mips, printing out arrays
# 36981     How to detach a managed object from Core Data?
# 36982  Winforms RichTextBox: How can I determine how ...
# 36983           ColdFusion Hibernate Generated Database
# 36984                      Thread sleep and thread join.
# 36985      regular expression: extract last 2 characters
# 36986                       Center button in custom view
# 36987       returning GMap location object from function
# 36988                Scripting Language vs. Java and C++
# 36989  What are the differences of ASP.NET MVC 4 and ...
# 36990  Changing combobox value of minimized applicati...
# 36991                              OutOFMemory exception
# 36992                Restricting available localizations
# 36993       how to change a dropdown menu to transparent
# 36994          How do I debug a failed commit to github?
# 36995                               change type using vb
# 36996          Get file upload as string (Ruby on rails)
# 36997  How to use a service class in a controller class?
# 36998  iphone opengl es how to add an image as the ba...
# 36999                           PHP GROUP AND SORT ARRAY
#
#                                             BodyMarkdown                Tag1  \
# 0      ![Get-values don't be refreshed][1]\r\r\n\r\r\...                 php
# 1      Suppose you're writing a program that searches...              search
# 2      I have this bit of jQuery toggling a paragraph...              jquery
# 3      \\I need to look through an array from east to...                java
# 4      I've created a simple custom dialog that asks ...             android
# 5      i build a simple Iphone App (Hello World) and ...              iphone
# 6      I am using Flex 4. Advanced Data grid. In that...                flex
# 7      Even when i type \r\r\n\r\r\n    echo strtr("-...                 php
# 8      Im trying to add bounding spheres to models fo...                  c#
# 9      Is hashing a password twice before storage any...            security
# 10     I am new to WP7 programming and I have been fo...         silverlight
# 11     Having code:\r\r\n\r\r\n    struct B\r\r\n    ...                 c++
# 12     I am developing a new project, using Autotools...                   c
# 13     I have two strings `str1` and `str2`. Check bo...          javascript
# 14     I know the IP address, VNC Password, VNC Port,...               linux
# 15     I'am using Configuration 1.6.\r\r\n\r\r\nI hav...                java
# 16     I am trying to use automation to login to a re...             windows
# 17     Write a program that uses nested loops to coll...              python
# 18     I have an Entity Data Model that I have create...                  c#
# 19     I have a simple question for a Comp Sci class ...                   c
# 20     this is the continuation of the following  2 l...                ajax
# 21     I have a table in my source DB that is self re...          sql-server
# 22     I have a pretty good understanding of what Int...             android
# 23         Public Sub delay(seconds As Long)\r\r\n   ...           excel-vba
# 24     here is my code, i can only add the node to th...                   c
# 25     if i do :\r\r\n\r\r\nstring = raw_string('Ente...              python
# 26     As far as theory goes it seems taht Asp.net MV...         asp.net-mvc
# 27     please suggest some way for efficient incremen...              string
# 28     I am looking for some example which can help m...                  c#
# 29     need some help here.  I have been administerin...               mysql
# ...                                                  ...                 ...
# 36970  Can u give an advice for this if its right or ...                  c#
# 36971  I get java code and xml code from file myproje...             android
# 36972  Can I have someone watch this for me? I want t...                 php
# 36973  I've been trying to make my own basic .obj (Wa...                 c++
# 36974  I'm trying to make a drop down table using jQu...              jquery
# 36975  I thought the C/C++ vs C#/Java performance que...                .net
# 36976  Im trying to build a form which uses AJAX but ...                ajax
# 36977  My script below changes a phrase of the array ...          javascript
# 36978  I keep running across this loading image\r\r\n...               image
# 36979  I am getting the following memeory leaks after...         objective-c
# 36980  I have to write a merge sort program that take...              arrays
# 36981  In a Core Data project, I've got two buttons o...              iphone
# 36982  I have a Winforms app containing a RichTextBox...            winforms
# 36983  Is the database generated by Hibernate when us...          coldfusion
# 36984  if i put a thread to sleep in a loop, netbeans...                java
# 36985  what is the best way to extract last 2 charact...             regular
# 36986  I've searched the Internet and these forums bu...         objective-c
# 36987  I'm trying to do a simple geocode function for...          javascript
# 36988  I was looking at some computer science videos ...                java
# 36989  More details, I know there are some templates ...                  c#
# 36990  I have a piece of closed-source third party wi...              autoit
# 36991  1) What are the possible reasons of OutofMemor...  garbage-collection
# 36992  Supposing I have two different languages for `...              iphone
# 36993  I have a dropdown menu and the css is backgrou...                html
# 36994  I'm new to git and github.  My first commit of...                 git
# 36995  piece of code :- \r\r\n\r\r\n\r\r\n> Dim objCo...              vb.net
# 36996      <h4>Upload CSV File:</h4> \r\r\n    <%= fo...       ruby-on-rails
# 36997  I'm trying to integrate [this amazing calendar...                 php
# 36998  \r\r\n\r\r\nthis is a project  of opengl es, y...              iphone
# 36999  I have an array \r\r\nArray\r\r\n\r\r\n(\r\r\n...                 php
#
#                        Tag2               Tag3            Tag4  \
# 0                    apache                NaN             NaN
# 1                   haskell    lazy-evaluation       inference
# 2                   firefox             toggle  preventdefault
# 3                    arrays                NaN             NaN
# 4                       sdk             dialog         onkeyup
# 5                     xcode        application           cydia
# 6                  datagrid                NaN             NaN
# 7               translation              strtr             NaN
# 8                       xna                NaN             NaN
# 9                      hash                NaN             NaN
# 10          windows-phone-7            twitter     overloading
# 11              constructor                NaN             NaN
# 12                      gcc      build-process       autotools
# 13                   string            compare         indexof
# 14                   upload                NaN             NaN
# 15                      NaN                NaN             NaN
# 16           remote-desktop       group-policy             gpo
# 17            error-message   input-validation             NaN
# 18         entity-framework           override             NaN
# 19                 assembly               mips             NaN
# 20                  struts2                NaN             NaN
# 21                     ssis                NaN             NaN
# 22                      NaN                NaN             NaN
# 23                      NaN                NaN             NaN
# 24                 homework                NaN             NaN
# 25               raw-string                NaN             NaN
# 26                      mvp                NaN             NaN
# 27         cluster-analysis                NaN             NaN
# 28                     .net                zip             NaN
# 29                 triggers        primary-key             NaN
# ...                     ...                ...             ...
# 36970                   NaN                NaN             NaN
# 36971                   NaN                NaN             NaN
# 36972                   NaN                NaN             NaN
# 36973                  sfml           opengl-3       wavefront
# 36974                  html              table             NaN
# 36975                   c++        performance       real-time
# 36976                   NaN                NaN             NaN
# 36977                jquery                NaN             NaN
# 36978             animation                NaN             NaN
# 36979                   ios       memory-leaks             NaN
# 36980              homework               mips       mergesort
# 36981             core-data                NaN             NaN
# 36982           richtextbox             scroll             NaN
# 36983             hibernate                NaN             NaN
# 36984        multithreading                NaN             NaN
# 36985            expression                NaN             NaN
# 36986                 xcode              cocoa             NaN
# 36987           geolocation  google-maps-api-3             NaN
# 36988                python          scripting        language
# 36989                  .net        asp.net-mvc   asp.net-mvc-3
# 36990            autohotkey            windows             NaN
# 36991  outofmemoryexception                NaN             NaN
# 36992                   ios                NaN             NaN
# 36993                   css                NaN             NaN
# 36994                github                NaN             NaN
# 36995                   NaN                NaN             NaN
# 36996                   NaN                NaN             NaN
# 36997                   oop     zend-framework           class
# 36998                opengl          opengl-es             NaN
# 36999                   NaN                NaN             NaN
#
#                           Tag5       PostClosedDate  OpenStatus
# 0                          NaN  08/10/2011 21:57:14           1
# 1                          NaN                  NaN           0
# 2                          NaN                  NaN           0
# 3                          NaN  12/07/2011 18:33:56           4
# 4                    onkeydown                  NaN           0
# 5                          NaN                  NaN           0
# 6                          NaN  10/07/2011 17:32:17           1
# 7                          NaN                  NaN           0
# 8                          NaN                  NaN           0
# 9                          NaN                  NaN           0
# 10                         NaN                  NaN           0
# 11                         NaN                  NaN           0
# 12                         NaN                  NaN           0
# 13                         NaN                  NaN           0
# 14                         NaN                  NaN           0
# 15                         NaN                  NaN           0
# 16     windows-xp-professional  07/25/2012 12:22:22           3
# 17                         NaN  10/13/2011 07:26:24           4
# 18                         NaN                  NaN           0
# 19                         NaN                  NaN           0
# 20                         NaN                  NaN           0
# 21                         NaN                  NaN           0
# 22                         NaN                  NaN           0
# 23                         NaN  02/07/2011 04:05:47           1
# 24                         NaN                  NaN           0
# 25                         NaN                  NaN           0
# 26                         NaN  04/04/2012 07:41:12           2
# 27                         NaN                  NaN           0
# 28                         NaN                  NaN           0
# 29                         NaN                  NaN           0
# ...                        ...                  ...         ...
# 36970                      NaN  06/26/2010 04:00:55           1
# 36971                      NaN  05/31/2012 21:29:52           1
# 36972                      NaN  04/05/2011 21:35:16           1
# 36973                    phong                  NaN           0
# 36974                      NaN                  NaN           0
# 36975                  finance                  NaN           0
# 36976                      NaN                  NaN           0
# 36977                      NaN  01/20/2012 13:23:14           1
# 36978                      NaN                  NaN           0
# 36979                      NaN                  NaN           0
# 36980                      NaN  04/10/2011 22:52:11           4
# 36981                      NaN                  NaN           0
# 36982                      NaN                  NaN           0
# 36983                      NaN                  NaN           0
# 36984                      NaN                  NaN           0
# 36985                      NaN                  NaN           0
# 36986                      NaN                  NaN           0
# 36987                      NaN                  NaN           0
# 36988     language-comparisons  09/17/2011 02:43:15           2
# 36989                    razor  04/13/2012 03:36:38           2
# 36990                      NaN                  NaN           0
# 36991                      NaN                  NaN           0
# 36992                      NaN                  NaN           0
# 36993                      NaN                  NaN           0
# 36994                      NaN                  NaN           0
# 36995                      NaN  04/10/2012 19:36:16           1
# 36996                      NaN                  NaN           0
# 36997       zend-framework-mvc                  NaN           0
# 36998                      NaN  01/09/2012 16:24:07           1
# 36999                      NaN  10/20/2011 03:38:39           1
#
# [37000 rows x 15 columns]>

# %%
q = data.head(37000)
q = q.drop(['PostId', 'PostCreationDate', 'OwnerUserId', 'PostClosedDate'], 1)
for i in range(0, len(q.axes[0])):
    date = q.get_value(i, 'OwnerCreationDate')
    if date.find('/') > 0:
        q.set_value(i, 'OwnerCreationDate', time.mktime(datetime.datetime.strptime(date, "%m/%d/%Y %H:%M:%S").timetuple()))
    elif len(date.split('-')[0]) > 2:
        q.set_value(i, 'OwnerCreationDate', time.mktime(datetime.datetime.strptime(date, "%Y-%m-%d").timetuple()))

# %% [markdown]
# ## Merge tags and title into body

# %%
q['BodyMarkdown'] = q.BodyMarkdown.astype(str).str.cat(q.Title.astype(str), sep=' ')
q = q.drop('Title', 1)
tags = ['Tag1', 'Tag2', 'Tag3', 'Tag4', 'Tag5']
q = q.fillna(' ')
q['Tags'] = q.Tag1 + ' ' + q.Tag2 + ' ' + q.Tag3 + ' ' + q.Tag4 + ' ' + q.Tag5

q['BodyMarkdown'] = q.BodyMarkdown.astype(str).str.cat(q.Tags.astype(str), sep=' ')
q = q.drop('Tags', 1)
q = q.drop(tags, 1)
#q.head(1)
#train = q['BodyMarkdown']

# %%
train = q['BodyMarkdown']
count_vect = CountVectorizer()
count_vect.stop_words = 'english'
X = count_vect.fit_transform(train)
tfidf_transformer = TfidfTransformer()
X = tfidf_transformer.fit_transform(X)

# %%
y = array(list(q['OpenStatus']))
new = q
new = new.drop(['BodyMarkdown', 'OpenStatus'], 1)
new = new.as_matrix()

# %%
scaler = MinMaxScaler()
new = scaler.fit_transform(new)
c = hstack([new, X])

# %% [markdown]
# ## Logistic regression

# %%
clf = LogisticRegression()
param_grid = {'penalty': ['l1'], 'C': arange(1, 3, 0.1), 'warm_start': [True], 'random_state': [42], 'solver': ['liblinear'], 'verbose': [1]}
clf = GridSearchCV(clf, param_grid, n_jobs=-1, refit=True)

clf.fit(c, y)
clf.best_score_, clf.best_params_
# Out:
# [LibLinear]
# (0.7169189189189189,
#  {'C': 1.7000000000000006,
#   'penalty': 'l1',
#   'random_state': 42,
#   'solver': 'liblinear',
#   'verbose': 1,
#   'warm_start': True})

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
clf = MultinomialNB()
param_grid = {'alpha': arange(0, 1, 0.001), 'fit_prior': [True, False]}
clf = GridSearchCV(clf, param_grid, n_jobs=-1, refit=True)

clf.fit(X, y)
clf.best_score_, clf.best_params_
# Out:
# (0.68193333333333328, {'alpha': 0.068000000000000005, 'fit_prior': True})

# %%
test_data = pd.read_csv('test.csv', encoding='cp1251')
origin = test_data

# %%
test_data = test_data.drop(['PostId', 'PostCreationDate', 'OwnerUserId'], 1)
for i in range(0, len(q.axes[0])):
    date = test_data.get_value(i, 'OwnerCreationDate')
    if date.find('/') > 0:
        test_data.set_value(i, 'OwnerCreationDate', time.mktime(datetime.datetime.strptime(date, "%m/%d/%Y %H:%M:%S").timetuple()))
    elif len(date.split('-')[0]) > 2:
        test_data.set_value(i, 'OwnerCreationDate', time.mktime(datetime.datetime.strptime(date, "%Y-%m-%d").timetuple()))
        
test_data['BodyMarkdown'] = test_data.BodyMarkdown.astype(str).str.cat(test_data.Title.astype(str), sep=' ')
test_data = test_data.drop('Title', 1)
tags = ['Tag1', 'Tag2', 'Tag3', 'Tag4', 'Tag5']
test_data = test_data.fillna(' ')
test_data['Tags'] = test_data.Tag1 + ' ' + test_data.Tag2 + ' ' + test_data.Tag3 + ' ' + test_data.Tag4 + ' ' + test_data.Tag5

test_data['BodyMarkdown'] = test_data.BodyMarkdown.astype(str).str.cat(test_data.Tags.astype(str), sep=' ')
test_data = test_data.drop('Tags', 1)
test_data = test_data.drop(tags, 1)

train = test_data['BodyMarkdown']
X_test = count_vect.transform(train)
X_test = tfidf_transformer.transform(X_test)

new = test_data
new = new.drop(['BodyMarkdown'], 1)
new = new.as_matrix()

scaler = MinMaxScaler()
new = scaler.fit_transform(new)
c = hstack([new, X])

clf = LogisticRegression(penalty='l2', C= 2.1, warm_start=True, dual=True, random_state=42, solver='liblinear', verbose=1)
clf.fit(X, y)
predicted = clf.predict(X_test)
# Out:
# [LibLinear]

# %%
results = pd.DataFrame(origin,columns=['PostId']).join(pd.DataFrame(predicted,columns=['OpenStatus']))
results.to_csv('submission.csv',index=False)

# %%
results
# Out:
#         PostId  OpenStatus
# 0       779052           0
# 1      3351926           4
# 2      2333077           0
# 3      1186402           0
# 4       589152           0
# 5      1242891           0
# 6       924451           0
# 7        47528           0
# 8       225881           0
# 9      2970394           2
# 10     1640608           0
# 11     1629418           0
# 12     2171522           0
# 13      611303           0
# 14     1525761           0
# 15     1228368           0
# 16     2972300           0
# 17      370025           0
# 18     2397746           0
# 19     2025669           0
# 20     1515849           0
# 21      208610           3
# 22     2247142           0
# 23     3011503           0
# 24       44645           0
# 25       60825           0
# 26      372641           0
# 27     3158482           0
# 28     3352497           0
# 29     1481154           0
# 30      596183           0
# 31     2161141           3
# 32     2815368           0
# 33     1361778           0
# 34     1785098           0
# 35      364574           0
# 36     3234586           0
# 37     1721381           0
# 38     1314358           0
# 39     1575581           0
# 40      929347           0
# 41      297836           2
# 42     2420093           0
